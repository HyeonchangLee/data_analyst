# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
#데이터 불러오기

df = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/project/데이터전처리/events.csv')


print(df.isna().sum()) #0

df = df.dropna(how='any')
# Out:
# event_time            0
# event_type            0
# product_id            0
# category_id           0
# category_code    236219
# brand            212364
# price                 0
# user_id               0
# user_session        165
# dtype: int64

# %%
print(df.isna().sum()) #0
# Out:
# event_time       0
# event_type       0
# product_id       0
# category_id      0
# category_code    0
# brand            0
# price            0
# user_id          0
# user_session     0
# dtype: int64

# %%
# df['event_type'].unique()


purchase=df[df['event_type'] == 'purchase']

# %%
purchase.to_csv('purchase.csv')

# %%
purchase
# Out:
#                      event_time event_type  product_id          category_id  \
# 45      2020-09-24 12:04:10 UTC   purchase     1507291  2144415926806642904
# 82      2020-09-24 12:15:06 UTC   purchase      822426  2144415922360680550
# 150     2020-09-24 12:29:49 UTC   purchase     1283197  2144415973413749245
# 199     2020-09-24 12:43:21 UTC   purchase      822426  2144415922360680550
# 215     2020-09-24 12:48:11 UTC   purchase      822426  2144415922360680550
# ...                         ...        ...         ...                  ...
# 885070  2021-02-28 23:16:45 UTC   purchase     4154620  2144415922427789416
# 885078  2021-02-28 23:20:48 UTC   purchase      500058  2144415923107266682
# 885082  2021-02-28 23:23:11 UTC   purchase      500058  2144415923107266682
# 885090  2021-02-28 23:26:07 UTC   purchase      500058  2144415923107266682
# 885096  2021-02-28 23:30:24 UTC   purchase     3829572  2144415924021624977
#
# ...

# %%
df2 = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/project/데이터전처리/ratings_Electronics.csv', names = ['userid', 'productid', 'rating','timestamp'])

# %%
# df2.isna().sum()
# Out:
# userid       0
# productid    0
# rating       0
# timestamp    0
# dtype: int64

# %%
df2.to_csv('ratings.csv')
