# %%
# bash 셸로 명령어 입력하여 라이브러리 설치하기

# %%bash
apt-get update
apt-get install g++ openjdk-8-jdk python-dev python3-dev
pip3 install JPype1
pip3 install konlpy
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease [1,581 B]
# Ign:2 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [824 kB]
# Get:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:7 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:9 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:10 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [85.6 kB]
# Hit:11 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# ...

# %%
# JAVA_HOME 환경변수 설정하기

# %env JAVA_HOME "/usr/lib/jvm/java-8-openjdk-amd64"
# Out:
# env: JAVA_HOME="/usr/lib/jvm/java-8-openjdk-amd64"

# %%
# okt 사용해보기 from konlpy
from konlpy.tag import Okt

# 형태소 분석
okt = Okt()

okt.pos('유일하게 항공기 제작이 가능한 곳입니다.',norm=True,stem=True) # 글과 품사에 대한 설명 추출
# [('유일하다', 'Adjective'),
#  ('항공기', 'Noun'),
#  ('제작', 'Noun'),
#  ('이', 'Josa'),
#  ('가능하다', 'Adjective'),
#  ('곳', 'Noun'),
#  ('이다', 'Adjective'),
#  ('.', 'Punctuation')]
# Out:
# ['단독', '입찰', '보다', '복수', '입찰', '일', '경우']

# %%
noun_zip = okt.nouns('유일하게 항공기 제작이 가능한 곳입니다.') #명사만 추출
# ['항공기', '제작', '곳']


# len(noun_zip)
# Out:
# 3

# %%
okt.morphs('단독 입찰보다 복수 입찰일 경우') #형태소 단위로 끊어 줌
# ['단독', '입찰', '보다', '복수', '입찰', '일', '경우']
# Out:
# ['단독', '입찰', '보다', '복수', '입찰', '일', '경우']

# %%
import pandas as pd

f = open('/content/reply01.csv',encoding='utf-8')
csv01 = f.read()

# print(csv01)


#형태소 분석
okt = Okt()

#어떤 글이 가장 많이 나왔는지 확인

word_dic = {}

lines = csv01.split('\n') #엔터 단위로 한 라인씩 가져옴
# print(lines[2]) #Apple 정품 애플펜슬 2세대,1,"Apple 정품 애플펜슬 2세대

for line in lines:
  #형태소 변환
  mal_list = okt.pos('')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-43a6e9aba0e9> in <module>()
#       1 import pandas as pd
#       2
# ----> 3 f = open('/content/reply01.csv',encoding='utf-8')
#       4 csv01 = f.read()
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/reply01.csv'
